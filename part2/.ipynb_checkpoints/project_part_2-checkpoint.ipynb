# %%
import argparse
import random
import math
import matplotlib.pyplot as plt
import networkx as nx
import os
import matplotlib.pyplot as plt
from numpy import array
import time
import math
import glob
import copy
import ast
from toolkit import *

# %%
test_cases = glob.glob('../data/*')

# %%
test_cases
# Out:
# ['../data\\K_10_C_50_S_3.txt',
#  '../data\\K_3_C_33_S_5.txt',
#  '../data\\K_3_C_60_S_20.txt',
#  '../data\\K_4_C_50_S_10.txt',
#  '../data\\K_6_C_50_S_7.txt']

# %%
index = 4

# %%
with open(test_cases[index]) as f:
    E = f.readline()
    P = f.readline()
    edges = f.readline()

# %%
E = ast.literal_eval(E.strip('\n'))
P = ast.literal_eval(P.strip('\n'))
edges = ast.literal_eval(edges.strip('\n'))

# %%
edges2 = edges

# %%
C = len(P) - 1

# %% [markdown]
# inserting into a list at an index is O(n), but the look up is O(1). This is better than what I previously attempted which is adding to a dict O(1), and look up possibly being O(n).

# %%
adj = [0 for x in range(0, C)]

# %%
# add all values to a list 
for i in range(0, C):
        adj[i] = Node(i, adj_start = P[i])

# %%
degree_doubly = [DoublyLinkedList() for x in range(0, C-1) ]

# %%
max_degree = 0 
# calculate degree
for i in range(0, C):
    deg = P[i + 1] - P[i]
    adj[i].degree = deg
    adj[i].degree_start = deg
    degree_doubly[deg].insert_at_start(adj[i])
    if deg > max_degree:
        max_degree = deg

# %%
ordered = LinkedList()

# %%
G = nx.Graph()
G.add_edges_from(edges)
pos = nx.spring_layout(G,k=0.25,iterations=25)

# %%
def smallest_last_deletion(i=None, start=None, max_degree=max_degree, degree_doubly=degree_doubly, adj=adj, ordered=ordered, debug=True, pos = pos):
        n = degree_doubly[i].start_node
        next_check = copy.copy(start)
        left_over = False
        while n is not None:
    
            print('new i:', i)
            if adj[n.course].deleted is None and i > 0:
               
                if debug:
                    debugger(adj=adj, degree_doubly=degree_doubly, n=n, max_degree=max_degree, pos=pos, edges=edges)

                adj[n.course].degree_when_deleted =  adj[n.course].degree
                adj[n.course].deleted = -1
                degree_doubly[i].delete_element_by_value(n.course)
                n.nref_degree_list = None
                n.pref_degree_list = None
                ordered.insert_at_start(n)
                ordered.traverse_list()
                degree_doubly[0].insert_at_start(n)
                adjacents = n.degree_start
                n.degree = 0
                next_check = copy.copy(i)
                updated_start = copy.copy(i)
                print(n.__dict__)
                for j in range(n.adj_start, n.adj_start + adjacents):
                    if adj[E[j]].deleted is None:
                        degree = adj[E[j]].degree
                        
                        
                        if adj[E[j]].pref_degree_list is None and adj[E[j]].nref_degree_list is None:
                            degree_doubly[degree].start_node = None
                        elif adj[E[j]].pref_degree_list is not None and adj[E[j]].nref_degree_list is None:
                            adj[E[j]].pref_degree_list.nref_degree_list = None
                        elif  adj[E[j]].pref_degree_list is None and adj[E[j]].nref_degree_list is not None:
                            degree_doubly[degree].start_node = adj[E[j]].nref_degree_list
                            adj[E[j]].nref_degree_list.pref_degree_list = None
                        elif adj[E[j]].pref_degree_list is not None and adj[E[j]].nref_degree_list is not None:
                            adj[E[j]].nref_degree_list.pref_degree_list = adj[E[j]].pref_degree_list
                            adj[E[j]].pref_degree_list.nref_degree_list = adj[E[j]].nref_degree_list
                        
                        adj[E[j]].nref_degree_list = None
                        adj[E[j]].pref_degree_list = None
                        degree_doubly[degree-1].insert_at_start(adj[E[j]])
                        adj[E[j]].degree = adj[E[j]].degree - 1
                        print(adj[E[j]].__dict__)
                        if adj[E[j]].degree == 0:
                            ordered.insert_at_start(adj[E[j]])
                            ordered.traverse_list()
                            adj[E[j]].degree_when_deleted =  adj[E[j]].degree
                            adj[E[j]].deleted = -1
                            del pos[adj[E[j]].course]
                            print(adj[E[j]].__dict__)
                        print('start:', start)
                        if (adj[E[j]].degree < next_check or adj[E[j]].degree < start) and adj[E[j]].degree < updated_start:
                            next_check = adj[E[j]].degree
                            updated_start = adj[E[j]].degree
                        if (adj[E[j]].degree < next_check or adj[E[j]].degree < start) and adj[E[j]].degree > updated_start:
                            left_over = True
                            left_over_degree = adj[E[j]].degree
                        if adj[E[j]].degree == next_check:
                            i = i + 1
                        
                    
                del pos[n.course]
            
            if i > next_check:
                print('Case 1:', next_check)
                if next_check == 0:
                    next_check = start
                n, adj, degree_doubly, ordered, pos = smallest_last_deletion(i=next_check, start=start, max_degree=max_degree, degree_doubly=degree_doubly, adj=adj, ordered=ordered, pos = pos)
                if n == None:
                    break
                else:
                    n = n.nref_degree_list
            elif degree_doubly[i].start_node is not None:
                print('Case 2:')
                if next_check == 0:
                    next_check = start
                n, adj, degree_doubly, ordered, pos = smallest_last_deletion(i=next_check, start=start, max_degree=max_degree, degree_doubly=degree_doubly, adj=adj, ordered=ordered, pos = pos)
                if n == None:
                    break
                else:
                    n = n.nref_degree_list
            if left_over:
                if degree_doubly[left_over_degree].start_node is not None:
                    print('Case 3:')
#                     if next_check == 0:
#                         next_check = left_over_degree
                    n, adj, degree_doubly, ordered, pos = smallest_last_deletion(i=left_over_degree, start=start, max_degree=max_degree, degree_doubly=degree_doubly, adj=adj, ordered=ordered, pos = pos)
                    if n == None:
                        break
                    else:
                        n = n.nref_degree_list
                elif degree_doubly[left_over_degree - 1].start_node is not None:
                    print('Case 4:')
#                     if next_check == 0:
#                         next_check = left_over_degree - 1
                    n, adj, degree_doubly, ordered, pos = smallest_last_deletion(i=left_over_degree - 1, start=start, max_degree=max_degree, degree_doubly=degree_doubly, adj=adj, ordered=ordered, pos = pos)
                    if n == None:
                        break
                    else:
                        n = n.nref_degree_list
            else:
                i = start
                print('Continue...')
                n = degree_doubly[i].start_node
                if n == None:
                    break
                else:
                    n = n.nref_degree_list
                
            
            
        return n, adj, degree_doubly, ordered, pos

# %%
for i in range(1, max_degree):
    print('------------------', i)
    n, adj, degree_doubly, ordered, pos = smallest_last_deletion(i=i, start=i, max_degree=max_degree, degree_doubly=degree_doubly, adj=adj, ordered=ordered, pos=pos)
# Out:
# ------------------ 1
# ------------------ 2
# ------------------ 3
# ------------------ 4
# ------------------ 5
# new i: 5
# course: 45
# list:  0
# [49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# List has no element
# list:  4
# List has no element
# list:  5
# [45, 44, 39, 38, 37, 33, 32, 29, 26, 24, 23, 18, 16, 10, 7, 6, 3, 2]
# list:  6
# List has no element
# list:  7
# List has no element
# list:  8
# [30, 1]
# list:  9
# [47, 43, 41]
# list:  10
# [31, 20, 14, 8]
# list:  11
# List has no element
# list:  12
# [36]
# list:  13
# [9]
# [45]
# {'course': 45, 'adj_start': 184, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C08390>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 5, 'ref': None}
# {'course': 1, 'adj_start': 0, 'degree': 7, 'degree_start': 8, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 20, 'adj_start': 76, 'degree': 9, 'degree_start': 10, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C08320>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 30, 'adj_start': 106, 'degree': 7, 'degree_start': 8, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFF978>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 31, 'adj_start': 114, 'degree': 9, 'degree_start': 10, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFDA0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 36, 'adj_start': 134, 'degree': 11, 'degree_start': 12, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 2:
# new i: 5
# course: 44
# list:  0
# [45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# List has no element
# list:  4
# List has no element
# list:  5
# [44, 39, 38, 37, 33, 32, 29, 26, 24, 23, 18, 16, 10, 7, 6, 3, 2]
# list:  6
# List has no element
# list:  7
# [30, 1]
# list:  8
# List has no element
# list:  9
# [31, 20, 47, 43, 41]
# list:  10
# [14, 8]
# list:  11
# [36]
# list:  12
# List has no element
# list:  13
# [9]
# [44, 45]
# {'course': 44, 'adj_start': 179, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C082B0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 5, 'ref': <toolkit.Node object at 0x0000022D13C082B0>}
# {'course': 7, 'adj_start': 23, 'degree': 4, 'degree_start': 5, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 14, 'adj_start': 56, 'degree': 9, 'degree_start': 10, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFF668>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 24, 'adj_start': 91, 'degree': 4, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFAC8>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 31, 'adj_start': 114, 'degree': 8, 'degree_start': 10, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 33, 'adj_start': 129, 'degree': 4, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFE80>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 4
# new i: 4
# course: 33
# list:  0
# [44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# List has no element
# list:  4
# [33, 24, 7]
# list:  5
# [39, 38, 37, 32, 29, 26, 23, 18, 16, 10, 6, 3, 2]
# list:  6
# List has no element
# list:  7
# [30, 1]
# list:  8
# [31]
# list:  9
# [14, 20, 47, 43, 41]
# list:  10
# [8]
# list:  11
# [36]
# list:  12
# List has no element
# list:  13
# [9]
# [33, 44, 45]
# {'course': 33, 'adj_start': 129, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C08278>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 4, 'ref': <toolkit.Node object at 0x0000022D13C08278>}
# {'course': 7, 'adj_start': 23, 'degree': 3, 'degree_start': 5, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 14, 'adj_start': 56, 'degree': 8, 'degree_start': 10, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFF668>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 24, 'adj_start': 91, 'degree': 3, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFAC8>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 31, 'adj_start': 114, 'degree': 7, 'degree_start': 10, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFFD0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 3
# new i: 3
# course: 24
# list:  0
# [33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# [24, 7]
# list:  4
# List has no element
# list:  5
# [39, 38, 37, 32, 29, 26, 23, 18, 16, 10, 6, 3, 2]
# list:  6
# List has no element
# list:  7
# [31, 30, 1]
# list:  8
# [14]
# list:  9
# [20, 47, 43, 41]
# list:  10
# [8]
# list:  11
# [36]
# list:  12
# List has no element
# list:  13
# [9]
# [24, 33, 44, 45]
# {'course': 24, 'adj_start': 91, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFF6A0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 3, 'ref': <toolkit.Node object at 0x0000022D13BFF6A0>}
# {'course': 7, 'adj_start': 23, 'degree': 2, 'degree_start': 5, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 14, 'adj_start': 56, 'degree': 7, 'degree_start': 10, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFF668>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 31, 'adj_start': 114, 'degree': 6, 'degree_start': 10, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 2
# new i: 2
# course: 7
# list:  0
# [24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# [7]
# list:  3
# List has no element
# list:  4
# List has no element
# list:  5
# [39, 38, 37, 32, 29, 26, 23, 18, 16, 10, 6, 3, 2]
# list:  6
# [31]
# list:  7
# [14, 30, 1]
# list:  8
# List has no element
# list:  9
# [20, 47, 43, 41]
# list:  10
# [8]
# list:  11
# [36]
# list:  12
# List has no element
# list:  13
# [9]
# [7, 24, 33, 44, 45]
# {'course': 7, 'adj_start': 23, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFE80>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 2, 'ref': <toolkit.Node object at 0x0000022D13BFFE80>}
# {'course': 14, 'adj_start': 56, 'degree': 6, 'degree_start': 10, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFF668>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 31, 'adj_start': 114, 'degree': 5, 'degree_start': 10, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C08160>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Continue...
# new i: 5
# course: 39
# list:  0
# [7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# List has no element
# list:  4
# List has no element
# list:  5
# [31, 39, 38, 37, 32, 29, 26, 23, 18, 16, 10, 6, 3, 2]
# list:  6
# [14]
# list:  7
# [30, 1]
# list:  8
# List has no element
# list:  9
# [20, 47, 43, 41]
# list:  10
# [8]
# list:  11
# [36]
# list:  12
# List has no element
# list:  13
# [9]
# [39, 7, 24, 33, 44, 45]
# {'course': 39, 'adj_start': 156, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFAC8>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 5, 'ref': <toolkit.Node object at 0x0000022D13BFFAC8>}
# {'course': 1, 'adj_start': 0, 'degree': 6, 'degree_start': 8, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFC50>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 8, 'adj_start': 28, 'degree': 9, 'degree_start': 10, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFDA0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 30, 'adj_start': 106, 'degree': 6, 'degree_start': 8, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFF978>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 36, 'adj_start': 134, 'degree': 10, 'degree_start': 12, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 41, 'adj_start': 161, 'degree': 8, 'degree_start': 9, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 2:
# new i: 5
# course: 31
# list:  0
# [39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# List has no element
# list:  4
# List has no element
# list:  5
# [31, 38, 37, 32, 29, 26, 23, 18, 16, 10, 6, 3, 2]
# list:  6
# [30, 1, 14]
# list:  7
# List has no element
# list:  8
# [41]
# list:  9
# [8, 20, 47, 43]
# list:  10
# [36]
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# [9]
# [31, 39, 7, 24, 33, 44, 45]
# {'course': 31, 'adj_start': 114, 'degree': 0, 'degree_start': 10, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C08160>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 5, 'ref': <toolkit.Node object at 0x0000022D13C08160>}
# {'course': 1, 'adj_start': 0, 'degree': 5, 'degree_start': 8, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C08128>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 14, 'adj_start': 56, 'degree': 5, 'degree_start': 10, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFF978>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 20, 'adj_start': 76, 'degree': 8, 'degree_start': 10, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C081D0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 30, 'adj_start': 106, 'degree': 5, 'degree_start': 8, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFC50>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 36, 'adj_start': 134, 'degree': 9, 'degree_start': 12, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFB00>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 5
# new i: 5
# course: 30
# list:  0
# [31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# List has no element
# list:  4
# List has no element
# list:  5
# [30, 14, 1, 38, 37, 32, 29, 26, 23, 18, 16, 10, 6, 3, 2]
# list:  6
# List has no element
# list:  7
# List has no element
# list:  8
# [20, 41]
# list:  9
# [36, 8, 47, 43]
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# [9]
# [30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 30, 'adj_start': 106, 'degree': 0, 'degree_start': 8, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFF668>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 5, 'ref': <toolkit.Node object at 0x0000022D13BFF668>}
# {'course': 1, 'adj_start': 0, 'degree': 4, 'degree_start': 8, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 8, 'adj_start': 28, 'degree': 8, 'degree_start': 10, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFDA0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 20, 'adj_start': 76, 'degree': 7, 'degree_start': 10, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 36, 'adj_start': 134, 'degree': 8, 'degree_start': 12, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFB00>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 41, 'adj_start': 161, 'degree': 7, 'degree_start': 9, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFDA0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 4
# new i: 4
# course: 1
# list:  0
# [30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# List has no element
# list:  4
# [1]
# list:  5
# [14, 38, 37, 32, 29, 26, 23, 18, 16, 10, 6, 3, 2]
# list:  6
# List has no element
# list:  7
# [41, 20]
# list:  8
# [36, 8]
# list:  9
# [47, 43]
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# [9]
# [1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 1, 'adj_start': 0, 'degree': 0, 'degree_start': 8, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFFD0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 4, 'ref': <toolkit.Node object at 0x0000022D13BFFFD0>}
# {'course': 8, 'adj_start': 28, 'degree': 7, 'degree_start': 10, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C081D0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 20, 'adj_start': 76, 'degree': 6, 'degree_start': 10, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 36, 'adj_start': 134, 'degree': 7, 'degree_start': 12, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFB00>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 41, 'adj_start': 161, 'degree': 6, 'degree_start': 9, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFDA0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Continue...
# new i: 5
# course: 38
# list:  0
# [1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# List has no element
# list:  4
# List has no element
# list:  5
# [14, 38, 37, 32, 29, 26, 23, 18, 16, 10, 6, 3, 2]
# list:  6
# [41, 20]
# list:  7
# [36, 8]
# list:  8
# List has no element
# list:  9
# [47, 43]
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# [9]
# [38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 38, 'adj_start': 151, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFF978>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 5, 'ref': <toolkit.Node object at 0x0000022D13BFF978>}
# {'course': 6, 'adj_start': 18, 'degree': 4, 'degree_start': 5, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 9, 'adj_start': 38, 'degree': 12, 'degree_start': 13, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 10, 'adj_start': 51, 'degree': 4, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFA90>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 26, 'adj_start': 96, 'degree': 4, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFB70>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 47, 'adj_start': 189, 'degree': 8, 'degree_start': 9, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 4
# new i: 4
# course: 26
# list:  0
# [38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# List has no element
# list:  4
# [26, 10, 6]
# list:  5
# [14, 37, 32, 29, 23, 18, 16, 3, 2]
# list:  6
# [41, 20]
# list:  7
# [36, 8]
# list:  8
# [47]
# list:  9
# [43]
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# [9]
# list:  13
# List has no element
# [26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 26, 'adj_start': 96, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C08128>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 4, 'ref': <toolkit.Node object at 0x0000022D13C08128>}
# {'course': 6, 'adj_start': 18, 'degree': 3, 'degree_start': 5, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 9, 'adj_start': 38, 'degree': 11, 'degree_start': 13, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 10, 'adj_start': 51, 'degree': 3, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFA90>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 47, 'adj_start': 189, 'degree': 7, 'degree_start': 9, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C080B8>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 3
# new i: 3
# course: 10
# list:  0
# [26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# [10, 6]
# list:  4
# List has no element
# list:  5
# [14, 37, 32, 29, 23, 18, 16, 3, 2]
# list:  6
# [41, 20]
# list:  7
# [47, 36, 8]
# list:  8
# List has no element
# list:  9
# [43]
# list:  10
# List has no element
# list:  11
# [9]
# list:  12
# List has no element
# list:  13
# List has no element
# [10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 10, 'adj_start': 51, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFEF0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 3, 'ref': <toolkit.Node object at 0x0000022D13BFFEF0>}
# {'course': 6, 'adj_start': 18, 'degree': 2, 'degree_start': 5, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 9, 'adj_start': 38, 'degree': 10, 'degree_start': 13, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 47, 'adj_start': 189, 'degree': 6, 'degree_start': 9, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C081D0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 2
# new i: 2
# course: 6
# list:  0
# [10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# [6]
# list:  3
# List has no element
# list:  4
# List has no element
# list:  5
# [14, 37, 32, 29, 23, 18, 16, 3, 2]
# list:  6
# [47, 41, 20]
# list:  7
# [36, 8]
# list:  8
# List has no element
# list:  9
# [43]
# list:  10
# [9]
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# List has no element
# [6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 6, 'adj_start': 18, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFB70>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 2, 'ref': <toolkit.Node object at 0x0000022D13BFFB70>}
# {'course': 9, 'adj_start': 38, 'degree': 9, 'degree_start': 13, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C08240>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 47, 'adj_start': 189, 'degree': 5, 'degree_start': 9, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFC50>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Continue...
# new i: 5
# course: 14
# list:  0
# [6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# List has no element
# list:  4
# List has no element
# list:  5
# [47, 14, 37, 32, 29, 23, 18, 16, 3, 2]
# list:  6
# [41, 20]
# list:  7
# [36, 8]
# list:  8
# List has no element
# list:  9
# [9, 43]
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# List has no element
# [14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 14, 'adj_start': 56, 'degree': 0, 'degree_start': 10, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFA90>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 5, 'ref': <toolkit.Node object at 0x0000022D13BFFA90>}
# {'course': 3, 'adj_start': 13, 'degree': 4, 'degree_start': 5, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 8, 'adj_start': 28, 'degree': 6, 'degree_start': 10, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C081D0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 16, 'adj_start': 66, 'degree': 4, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFF9E8>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 29, 'adj_start': 101, 'degree': 4, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFCC0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 32, 'adj_start': 124, 'degree': 4, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFF98>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 4
# new i: 4
# course: 32
# list:  0
# [14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# List has no element
# list:  4
# [32, 29, 16, 3]
# list:  5
# [47, 37, 23, 18, 2]
# list:  6
# [8, 41, 20]
# list:  7
# [36]
# list:  8
# List has no element
# list:  9
# [9, 43]
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# List has no element
# [32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 32, 'adj_start': 124, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFC50>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 4, 'ref': <toolkit.Node object at 0x0000022D13BFFC50>}
# {'course': 3, 'adj_start': 13, 'degree': 3, 'degree_start': 5, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 8, 'adj_start': 28, 'degree': 5, 'degree_start': 10, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C08320>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 16, 'adj_start': 66, 'degree': 3, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFF9E8>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 29, 'adj_start': 101, 'degree': 3, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFCC0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 3
# new i: 3
# course: 29
# list:  0
# [32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# [29, 16, 3]
# list:  4
# List has no element
# list:  5
# [8, 47, 37, 23, 18, 2]
# list:  6
# [41, 20]
# list:  7
# [36]
# list:  8
# List has no element
# list:  9
# [9, 43]
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# List has no element
# [29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 29, 'adj_start': 101, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFF630>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 3, 'ref': <toolkit.Node object at 0x0000022D13BFF630>}
# {'course': 3, 'adj_start': 13, 'degree': 2, 'degree_start': 5, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 8, 'adj_start': 28, 'degree': 4, 'degree_start': 10, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 16, 'adj_start': 66, 'degree': 2, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFF9E8>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 2
# new i: 2
# course: 16
# list:  0
# [29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# [16, 3]
# list:  3
# List has no element
# list:  4
# [8]
# list:  5
# [47, 37, 23, 18, 2]
# list:  6
# [41, 20]
# list:  7
# [36]
# list:  8
# List has no element
# list:  9
# [9, 43]
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# List has no element
# [16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 16, 'adj_start': 66, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFF98>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 2, 'ref': <toolkit.Node object at 0x0000022D13BFFF98>}
# {'course': 3, 'adj_start': 13, 'degree': 1, 'degree_start': 5, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 8, 'adj_start': 28, 'degree': 3, 'degree_start': 10, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 1
# new i: 1
# course: 3
# list:  0
# [16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# [3]
# list:  2
# List has no element
# list:  3
# [8]
# list:  4
# List has no element
# list:  5
# [47, 37, 23, 18, 2]
# list:  6
# [41, 20]
# list:  7
# [36]
# list:  8
# List has no element
# list:  9
# [9, 43]
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# List has no element
# [3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 3, 'adj_start': 13, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFCC0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 1, 'ref': <toolkit.Node object at 0x0000022D13BFFCC0>}
# {'course': 8, 'adj_start': 28, 'degree': 2, 'degree_start': 10, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 3:
# new i: 2
# course: 8
# list:  0
# [3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# [8]
# list:  3
# List has no element
# list:  4
# List has no element
# list:  5
# [47, 37, 23, 18, 2]
# list:  6
# [41, 20]
# list:  7
# [36]
# list:  8
# List has no element
# list:  9
# [9, 43]
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# List has no element
# [8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 8, 'adj_start': 28, 'degree': 0, 'degree_start': 10, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFF9E8>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 2, 'ref': <toolkit.Node object at 0x0000022D13BFF9E8>}
# {'course': 36, 'adj_start': 134, 'degree': 6, 'degree_start': 12, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C081D0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 41, 'adj_start': 161, 'degree': 5, 'degree_start': 9, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C08320>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Continue...
# new i: 5
# course: 47
# list:  0
# [8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# List has no element
# list:  4
# List has no element
# list:  5
# [41, 47, 37, 23, 18, 2]
# list:  6
# [36, 20]
# list:  7
# List has no element
# list:  8
# List has no element
# list:  9
# [9, 43]
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# List has no element
# [47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 47, 'adj_start': 189, 'degree': 0, 'degree_start': 9, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFB00>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 5, 'ref': <toolkit.Node object at 0x0000022D13BFFB00>}
# {'course': 2, 'adj_start': 8, 'degree': 4, 'degree_start': 5, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 9, 'adj_start': 38, 'degree': 8, 'degree_start': 13, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 20, 'adj_start': 76, 'degree': 5, 'degree_start': 10, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C081D0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 23, 'adj_start': 86, 'degree': 4, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFF9B0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 43, 'adj_start': 170, 'degree': 8, 'degree_start': 9, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFB38>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 4
# new i: 4
# course: 23
# list:  0
# [47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# List has no element
# list:  4
# [23, 2]
# list:  5
# [20, 41, 37, 18]
# list:  6
# [36]
# list:  7
# List has no element
# list:  8
# [43, 9]
# list:  9
# List has no element
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# List has no element
# [23, 47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 23, 'adj_start': 86, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C08320>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 4, 'ref': <toolkit.Node object at 0x0000022D13C08320>}
# {'course': 2, 'adj_start': 8, 'degree': 3, 'degree_start': 5, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 9, 'adj_start': 38, 'degree': 7, 'degree_start': 13, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 20, 'adj_start': 76, 'degree': 4, 'degree_start': 10, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 43, 'adj_start': 170, 'degree': 7, 'degree_start': 9, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFB38>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 3
# new i: 3
# course: 2
# list:  0
# [23, 47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# [2]
# list:  4
# [20]
# list:  5
# [41, 37, 18]
# list:  6
# [36]
# list:  7
# [43, 9]
# list:  8
# List has no element
# list:  9
# List has no element
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# List has no element
# [2, 23, 47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 2, 'adj_start': 8, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFE48>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 3, 'ref': <toolkit.Node object at 0x0000022D13BFFE48>}
# {'course': 9, 'adj_start': 38, 'degree': 6, 'degree_start': 13, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C080B8>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 20, 'adj_start': 76, 'degree': 3, 'degree_start': 10, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 43, 'adj_start': 170, 'degree': 6, 'degree_start': 9, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFB38>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 3
# new i: 3
# course: 20
# list:  0
# [2, 23, 47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# [20]
# list:  4
# List has no element
# list:  5
# [41, 37, 18]
# list:  6
# [43, 9, 36]
# list:  7
# List has no element
# list:  8
# List has no element
# list:  9
# List has no element
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# List has no element
# [20, 2, 23, 47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 20, 'adj_start': 76, 'degree': 0, 'degree_start': 10, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFF9B0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 3, 'ref': <toolkit.Node object at 0x0000022D13BFF9B0>}
# {'course': 9, 'adj_start': 38, 'degree': 5, 'degree_start': 13, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C081D0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 36, 'adj_start': 134, 'degree': 5, 'degree_start': 12, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFB38>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 43, 'adj_start': 170, 'degree': 5, 'degree_start': 9, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C080B8>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Continue...
# new i: 5
# course: 36
# list:  0
# [20, 2, 23, 47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# List has no element
# list:  4
# List has no element
# list:  5
# [43, 36, 9, 41, 37, 18]
# list:  6
# List has no element
# list:  7
# List has no element
# list:  8
# List has no element
# list:  9
# List has no element
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# List has no element
# [36, 20, 2, 23, 47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 36, 'adj_start': 134, 'degree': 0, 'degree_start': 12, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFDA0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 5, 'ref': <toolkit.Node object at 0x0000022D13BFFDA0>}
# {'course': 9, 'adj_start': 38, 'degree': 4, 'degree_start': 13, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 18, 'adj_start': 71, 'degree': 4, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFB38>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 37, 'adj_start': 146, 'degree': 4, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFD30>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 41, 'adj_start': 161, 'degree': 4, 'degree_start': 9, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C080F0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 43, 'adj_start': 170, 'degree': 4, 'degree_start': 9, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C081D0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 4
# new i: 4
# course: 43
# list:  0
# [36, 20, 2, 23, 47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# List has no element
# list:  4
# [43, 41, 37, 18, 9]
# list:  5
# List has no element
# list:  6
# List has no element
# list:  7
# List has no element
# list:  8
# List has no element
# list:  9
# List has no element
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# List has no element
# [43, 36, 20, 2, 23, 47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 43, 'adj_start': 170, 'degree': 0, 'degree_start': 9, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C080B8>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 4, 'ref': <toolkit.Node object at 0x0000022D13C080B8>}
# {'course': 9, 'adj_start': 38, 'degree': 3, 'degree_start': 13, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 18, 'adj_start': 71, 'degree': 3, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFB38>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 37, 'adj_start': 146, 'degree': 3, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFD30>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 41, 'adj_start': 161, 'degree': 3, 'degree_start': 9, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C080F0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 3
# new i: 3
# course: 41
# list:  0
# [43, 36, 20, 2, 23, 47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# List has no element
# list:  3
# [41, 37, 18, 9]
# list:  4
# List has no element
# list:  5
# List has no element
# list:  6
# List has no element
# list:  7
# List has no element
# list:  8
# List has no element
# list:  9
# List has no element
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# List has no element
# [41, 43, 36, 20, 2, 23, 47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 41, 'adj_start': 161, 'degree': 0, 'degree_start': 9, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C08240>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 3, 'ref': <toolkit.Node object at 0x0000022D13C08240>}
# {'course': 9, 'adj_start': 38, 'degree': 2, 'degree_start': 13, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 18, 'adj_start': 71, 'degree': 2, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFB38>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 37, 'adj_start': 146, 'degree': 2, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFD30>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 2
# new i: 2
# course: 37
# list:  0
# [41, 43, 36, 20, 2, 23, 47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# List has no element
# list:  2
# [37, 18, 9]
# list:  3
# List has no element
# list:  4
# List has no element
# list:  5
# List has no element
# list:  6
# List has no element
# list:  7
# List has no element
# list:  8
# List has no element
# list:  9
# List has no element
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# List has no element
# [37, 41, 43, 36, 20, 2, 23, 47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 37, 'adj_start': 146, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C081D0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 2, 'ref': <toolkit.Node object at 0x0000022D13C081D0>}
# {'course': 9, 'adj_start': 38, 'degree': 1, 'degree_start': 13, 'deleted': None, 'nref_degree_list': None, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# {'course': 18, 'adj_start': 71, 'degree': 1, 'degree_start': 5, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFB38>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# start: 5
# Case 1: 1
# new i: 1
# course: 18
# list:  0
# [37, 41, 43, 36, 20, 2, 23, 47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45, 49, 48, 46, 42, 40, 35, 34, 28, 27, 25, 22, 21, 19, 17, 15, 13, 12, 11, 5, 4, 0]
# list:  1
# [18, 9]
# list:  2
# List has no element
# list:  3
# List has no element
# list:  4
# List has no element
# list:  5
# List has no element
# list:  6
# List has no element
# list:  7
# List has no element
# list:  8
# List has no element
# list:  9
# List has no element
# list:  10
# List has no element
# list:  11
# List has no element
# list:  12
# List has no element
# list:  13
# List has no element
# [18, 37, 41, 43, 36, 20, 2, 23, 47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 18, 'adj_start': 71, 'degree': 0, 'degree_start': 5, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13C080F0>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 1, 'ref': <toolkit.Node object at 0x0000022D13C080F0>}
# {'course': 9, 'adj_start': 38, 'degree': 0, 'degree_start': 13, 'deleted': None, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFD30>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': None}
# [9, 18, 37, 41, 43, 36, 20, 2, 23, 47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]
# {'course': 9, 'adj_start': 38, 'degree': 0, 'degree_start': 13, 'deleted': -1, 'nref_degree_list': <toolkit.Node object at 0x0000022D13BFFD30>, 'pref_degree_list': None, 'color': -1, 'degree_when_deleted': 0, 'ref': <toolkit.Node object at 0x0000022D13BFFD30>}
# start: 5
# Case 1: 0
# ------------------ 6
# ------------------ 7
# ------------------ 8
# ------------------ 9
# ------------------ 10
# ------------------ 11
# ------------------ 12

# %%
coloring_order = ordered.traverse_list()
# Out:
# [9, 18, 37, 41, 43, 36, 20, 2, 23, 47, 8, 3, 16, 29, 32, 14, 6, 10, 26, 38, 1, 30, 31, 39, 7, 24, 33, 44, 45]

# %%
for x in adj:
    x.color = -1

# %%
def crayon(coloring_order=coloring_order, adj=adj, max_degree=max_degree):
    
    for course in coloring_order:
        print('course:', course)
        if adj[course].degree_start > 0:
            taken = []
            options = [-1] * max_degree
            for j in range(adj[course].adj_start, adj[course].adj_start + adj[course].degree_start):
                if adj[E[j]].color >= 0:
                    taken.append(adj[E[j]].color)
            if len(taken) == 0:
                adj[course].color = 0
            elif len(taken) > 0:
                for i in taken:
                    options[i] = 1
                
            print(taken)
            for k in range(0,len(options)):
                if options[k] == -1:
                    print('c:', k)
                    adj[course].color = k
                    break
    
    return adj

# %%
adj = crayon(coloring_order, adj)
# Out:
# course: 9
# []
# c: 0
# course: 18
# [0]
# c: 1
# course: 37
# [0, 1]
# c: 2
# course: 41
# [0, 1, 2]
# c: 3
# course: 43
# [0, 1, 2, 3]
# c: 4
# course: 36
# [0, 1, 2, 3, 4]
# c: 5
# course: 20
# [0, 5, 4]
# c: 1
# course: 2
# [0, 1, 4]
# c: 2
# course: 23
# [2, 0, 1, 4]
# c: 3
# course: 47
# [2, 0, 1, 3, 4]
# c: 5
# course: 8
# [5, 3]
# c: 0
# course: 3
# [0]
# c: 1
# course: 16
# [1, 0]
# c: 2
# course: 29
# [1, 0, 2]
# c: 3
# course: 32
# [1, 0, 2, 3]
# c: 4
# course: 14
# [1, 0, 2, 3, 4]
# c: 5
# course: 6
# [0, 5]
# c: 1
# course: 10
# [1, 0, 5]
# c: 2
# course: 26
# [1, 0, 2, 5]
# c: 3
# course: 38
# [1, 0, 2, 3, 5]
# c: 4
# course: 1
# [0, 1, 5, 3]
# c: 2
# course: 30
# [2, 0, 1, 5, 3]
# c: 4
# course: 31
# [2, 5, 1, 4, 5]
# c: 0
# course: 39
# [2, 0, 4, 5, 3]
# c: 1
# course: 7
# [5, 0]
# c: 1
# course: 24
# [1, 5, 0]
# c: 2
# course: 33
# [1, 5, 2, 0]
# c: 3
# course: 44
# [1, 5, 2, 0, 3]
# c: 4
# course: 45
# [2, 1, 4, 0, 5]
# c: 3

# %%
colors = []
for n in coloring_order:
    if adj[n].degree_start >= 1:
        colors.append(adj[n].color)

# %%
colors_dict = dict( (l, colors.count(l) ) for l in set(colors))

# %%
print('Number of colors:', len(colors_dict.keys()))
# Out:
# Number of colors: 6

# %%
color_map = {0: 'blue', 1: 'green', 2:'black', 3: 'red', 4: 'orange', 5:'purple', 6:'violet', 7:'hotpink', 8:'chocolate', 9:'palegreen', 10:'thistle' }

# %%
color_graph= [color_map[k] for k in colors]

# %%
G = nx.Graph()
G.add_edges_from(edges2)
pos = nx.spring_layout(G,k=0.25,iterations=25)

# %%
courses_per = int(test_cases[index].split('_')[1])
students = int(test_cases[index].split('_')[5].strip('.txt'))

# %%
network_vis2(Edges=edges2, pos=pos, courses_per=courses_per, students=students, classes=C, nodes=coloring_order, colors=color_graph)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4282                     valid_shape = False
# -> 4283                     raise ValueError
#    4284             except ValueError:
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-2944499854f5> in <module>
# ----> 1 network_vis2(Edges=edges2, pos=pos, courses_per=courses_per, students=students, classes=C, nodes=coloring_order, colors=color_graph)
#
# ~\Documents\Masters CS\CSE7350\project\part2\toolkit.py in network_vis2(Edges, pos, courses_per, students, classes, colors, nodes)
#     311     #print(pos)
#     312     # the histogram of the data
# --> 313     nx.draw(G, with_labels=True, pos=pos, node_color=colors )
#     314     ax.set_xlabel('Course')
#     315     ax.set_ylabel('Frequency')
#
# ~\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py in draw(G, pos, ax, **kwds)
#     123         kwds['with_labels'] = 'labels' in kwds
#     124
# --> 125     draw_networkx(G, pos=pos, ax=ax, **kwds)
#     126     ax.set_axis_off()
#     127     plt.draw_if_interactive()
#
# ~\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     272         pos = nx.drawing.spring_layout(G)  # default to spring layout
#     273
# --> 274     node_collection = draw_networkx_nodes(G, pos, **kwds)
#     275     edge_collection = draw_networkx_edges(G, pos, arrows=arrows, **kwds)
#     276     if with_labels:
#
# ~\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label, **kwds)
#     415                                  linewidths=linewidths,
#     416                                  edgecolors=edgecolors,
# --> 417                                  label=label)
#     418     ax.tick_params(
#     419         axis='both',
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4444             self._parse_scatter_color_args(
#    4445                 c, edgecolors, kwargs, xshape, yshape,
# -> 4446                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4447
#    4448         if plotnonfinite and colors is None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4288                         "acceptable for use with 'x' with size {xs}, "
#    4289                         "'y' with size {ys}."
# -> 4290                             .format(nc=n_elem, xs=xsize, ys=ysize)
#    4291                     )
#    4292                 else:
#
# ValueError: 'c' argument has 6 elements, which is not acceptable for use with 'x' with size 29, 'y' with size 29.

# %%
when_deleted_plot = []
for x in coloring_order:
    when_deleted_plot.insert(0, adj[x].degree_when_deleted)

# %%
# for plotting
fig, ax = plt.subplots(1)
# the histogram of the data
ax.plot(when_deleted_plot)
ax.set_xlabel('Deleted Order')
#ax.set_yticks([1,2,3])
ax.set_ylabel('Degree')
ax.set_title('Degree when deleted for C: %d, S: %d, K: %d' % (C, students, courses_per) )
plt.show()
